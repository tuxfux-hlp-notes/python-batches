# %%
print "hello world"
# Out:
# hello world

# %%
help()
# Out:
# Welcome to Python 2.7!  This is the online help utility.
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at http://docs.python.org/2.7/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, or topics, type "modules",
# "keywords", or "topics".  Each module also comes with a one-line summary
# of what it does; to list the modules whose summaries contain a given word
# such as "spam", type "modules spam".
#
# help> topics
#
# Here is a list of available topics.  Enter any topic name to get more help.
#
# ASSERTION           DEBUGGING           LITERALS            SEQUENCEMETHODS2
# ASSIGNMENT          DELETION            LOOPING             SEQUENCES
# ATTRIBUTEMETHODS    DICTIONARIES        MAPPINGMETHODS      SHIFTING
# ...

# %%
my_string="python"

# %%
my_string.capitalize()
# Out:
# 'Python'

# %% [raw]
# # ipython console based interpreter.
# In [1]: my_string="python"
#
# In [2]: my_string.capitalize?
# Docstring:
# S.capitalize() -> string
#
# Return a copy of the string S with only its first character
# capitalized.
# Type:      builtin_function_or_method
#
# In [3]: my_string.capitalize?
# Docstring:
# S.capitalize() -> string
#
# Return a copy of the string S with only its first character
# capitalized.
# Type:      builtin_function_or_method
#
# In [4]: my_string.capitalize??
# Type: builtin_function_or_method
#
# In [5]: my_string.capitalize()
# Out[5]: 'Python'
#
# In [6]: my_string.
#               my_string.capitalize my_string.endswith   my_string.isalnum    my_string.istitle
#               my_string.center     my_string.expandtabs my_string.isalpha    my_string.isupper
#               my_string.count      my_string.find       my_string.isdigit    my_string.join       >
#               my_string.decode     my_string.format     my_string.islower    my_string.ljust
#               my_string.encode     my_string.index      my_string.isspace    my_string.lower

# %% [raw]
# tcloudost@tcloudost-VirtualBox ~/Documents/git_repositories/python-batches/batch-59 $ python
# Python 2.7.6 (default, Jun 22 2015, 17:58:13)
# [GCC 4.8.2] on linux2
# Type "help", "copyright", "credits" or "license" for more information.
# >>>
# >>> my_string="python"
# >>> print dir(my_string)
# ['__add__', '__class__', '__contains__', '__delattr__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getslice__', '__gt__', '__hash__', '__init__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_formatter_field_name_split', '_formatter_parser', 'capitalize', 'center', 'count', 'decode', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'index', 'isalnum', 'isalpha', 'isdigit', 'islower', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
# >>> print help(my_string.upper)
#
# None
# >>> my_string.upper()
# 'PYTHON'
# >>>
#
#
# Play wiht my_string.<funtions> to see what they do one by one.
